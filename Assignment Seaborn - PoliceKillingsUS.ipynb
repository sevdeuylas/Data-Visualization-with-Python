# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv("PoliceKillingsUS.csv", encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill['manner_of_death'].unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
sns.boxplot(x='gender', y='age', hue='manner_of_death', data=kill);

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
fig, ax = plt.subplots (figsize=(10,6))
sns.swarmplot(x='gender', y='age', hue='manner_of_death', data=kill);

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
city_fr = kill.city.value_counts()[:12]
city_fr
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Indianapolis     14
# Name: city, dtype: int64

# %%
city_fr.index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Las Vegas',
#        'San Antonio', 'Columbus', 'Austin', 'Miami', 'St. Louis',
#        'Oklahoma City', 'Indianapolis'],
#       dtype='object')

# %%
city_fr.values
# Out:
# array([39, 31, 27, 25, 21, 20, 19, 18, 18, 15, 14, 14])

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(x=city_fr.index, y=city_fr.values, data=kill)
ax.set_title('Most dangerous cities', color='blue', fontsize=14)
ax.set_xticklabels(city_fr.index, rotation=45);

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.countplot(x= 'city', order=kill.city.value_counts()[:12].index, data=kill)
ax.set_title('Most dangerous cities', color='blue', fontsize=14)
ax.set_xticklabels(city_fr.index, rotation=45);

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
state_fr = kill.state.value_counts()[:20]
state_fr
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# WA     62
# IL     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
state_fr.index
# Out:
# Index(['CA', 'TX', 'FL', 'AZ', 'OH', 'OK', 'CO', 'GA', 'NC', 'MO', 'WA', 'IL',
#        'TN', 'LA', 'PA', 'NM', 'AL', 'VA', 'NY', 'SC'],
#       dtype='object')

# %%
state_fr.values
# Out:
# array([424, 225, 154, 118,  79,  78,  74,  70,  69,  64,  62,  62,  59,
#         57,  51,  51,  50,  47,  45,  44])

# %%
# with seaborn barplot
fig, ax = plt.subplots(figsize=(8,5))
ax = sns.barplot(x=state_fr.index, y=state_fr.values, data=kill)
ax.set_title('Most dangerous states', color='b', fontsize=14)
ax.set_xticklabels(state_fr.index, rotation=45);

# %%
# with seaborn countplot
fig, ax = plt.subplots(figsize=(8,5))
sns.countplot(x='state', order=state_fr.index, data=kill)
ax.set_title('Most dangerous states')
ax.set_xticklabels(state_fr.index, rotation=45);

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
kill.signs_of_mental_illness.value_counts()
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn
sns.countplot(kill.signs_of_mental_illness);

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
kill.threat_level.value_counts()
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
# with seaborn
sns.countplot(kill.threat_level);

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
kill.flee.value_counts()
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
# with seaborn
sns.countplot(x='flee', data=kill);
